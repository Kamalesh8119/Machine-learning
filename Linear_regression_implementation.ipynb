# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error,precision_score,recall_score,accuracy_score

# %% [markdown]
# Employee salary prediction dataset

# %%
df=pd.read_csv('/content/Salary_Data.csv')
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %% [markdown]
# Split the dataset into independent(X) and dependent(Y) variables

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
type(df.iloc[:, :-1])      # pandas DataFrame
type(df.iloc[:, :-1].values) # numpy.ndarray
# Out:
# numpy.ndarray

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %% [markdown]
# Divide the complete dataset into training and testing data

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0,test_size=0.3)

# %% [markdown]
# Implement Classifier based on Simple Linear Regression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
accuracy = r2_score(y_test, y_pred) * 100
print("Model Accuracy:", accuracy,"%")
# Out:
# Model Accuracy: 97.4099340721351 %

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2  = r2_score(y_test, y_pred)

print("MSE:", mse)
print("MAE:", mae)
print("R2 Score:", r2)
# Out:
# MSE: 23370078.800832972
# MAE: 3737.417861878896
# R2 Score: 0.9740993407213511

# %%
print("slope(coefficient)",model.coef_)
print("intercept",model.intercept_)
# Out:
# slope(coefficient) [9360.26128619]
# intercept 26777.391341197625

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Actual Salary")
plt.ylabel("Predicted Salary")
plt.title("Actual vs Predicted Salary")
plt.plot([min(y_test),max(y_test)],[min(y_pred),max(y_pred)],color='red')
plt.show()

# %% [markdown]
# This means:
#
# Predictions are highly accurate
#
# Errors are small
#
# The model generalizes well to unseen data
#
# This visually confirms a high R² score.

# %% [markdown]
# Testing on unseen data

# %%
experience = [[5]]
predicted_salary = model.predict(experience)
print("Predicted Salary for 5 years experience:", predicted_salary)
# Out:
# Predicted Salary for 5 years experience: [73578.69777217]
